# %%
c = 'YOODM RJUOZ INNWR MVZKA OVQTX AKSIY QFKBX CNIEB IOYVL TETXL NMZTL LXMVP NZKKX FFSVG EXJAR WHZKL XKVJU ASVKL QWRIF PYPMB IIYAR ZSFLO KAMXU SONSC RVPXS WDHVX LLGLD QGDZI CBMEZ ASWRL UVVGE WUOKJ IENJM QTSJY SAYDJ KGPIC JPXME NMSOB XPWVP BLPUS KQREJ EDQWD MPPBI OFUEU FPWVP XPLHL CLSHS VBCTE MLKTT SFIOB HPYLB UMYJK LGXSJ JYZVP XWYVH TSNVM XEJYS VXSJR OGAZW KDPMD XFCBI XTMOV GCDWD QSYTM PMVDF IKAMN DLDPM DYVBQ GLQSI AMRSP PQGLS ACBIA KVBEE CIPXB LPFAD MQAYA YUEVJ JYLIO RLCAE RJZEV VPFKK JPPKV BUEYD FOIVD NAGIW CJUYE RPIHC BLPNU NMGTU OOZEM QLMQT SJYNC IETAR MHTKM SKYWY FSBTC JZOVX PIPXK VJUAK VEWDZ SAMEB HCVXF SASTX SJARK IYYBB GXSFA MPECQ LCJEM GHQME YISKB ICNUN MTPSK OVXWD MBQIO WPMPO LXPCS MMWVU MXSJJ SXLPW YODIL QPXOX SJDOI OYJZC MWTSP DATZQ FKTTS FIOBM NXFCB IXYOS AFCJH UBLCT BQPQL WROLE DNNXQ JTHHX BQZRL XBMYH YIXXZ LYKXL THOSA XZWFN MQZSZ DZEEN UQBLP JCYTZ TSNMP EWQLX OIZKZ OKYCJ JYUQF SPMIX TTU'
c = c.replace(' ', '', )
c
# Out:
# '...'

# %%
key = 'FHKIEL'
ES = VigenereCryptosystem(AlphabeticStrings(),len(key))
_k = ES.encoding(key)
_c = ES.encoding(c)
ES.deciphering(_k,_c)
# Out:
# ...
