# %% [markdown]
# We want to be able to:
#
# - connect Python with a MySQL database
# - be able to manage a MYSQL database from Python (e.g. creating databases and tables, inserting data, deleting tables, ...)
# - write Pandas DataFrames to a MySQL database
# - read data from a MySQL database into a Pandas DataFrame
# - use SQL queries to filter data in a MySQL database

# %%
# %pip install SQLAlchemy mysql-connector-python python-dotenv

# %%
from sqlalchemy import create_engine, text   # Needed to connect to the database
import pandas as pd
import os                                    # Needed to access environment variables
from dotenv import load_dotenv               # Load passwords etc from .env file

# %% [markdown]
# ## 1.1 Connect to MySQL Database

# %% [markdown]
# - Instead of writing your database credentials into a Python script or Jupyter Notebook, you can store them in a separate .env file.
# - This is a text file that contains environment variables in the form of name=value pairs.
# - You can then load these variables into your Python script using the dotenv package.
# - Such a .env file should never be shared with others or checked into version control.

# %%
# Load the .env file
load_dotenv('.env', override=True)
# Out:
# True

# %% [markdown]
# - The package SQLAlchemy allows you to connect to different SQL databases (e.g. MySQL, PostgreSQL, SQLite, ...).
# - To connect to a MySQL database, you need to specify both the database dialect (mysql) and choose an appropriate driver (mysqlconnector, pymysql, ...). The driver needs to be installed separately. [MySQL Connector/Python](https://dev.mysql.com/doc/connector-python/en/connector-python-introduction.html) is the official MySQL driver for Python.

# %%
# Connection to local MYSQL database
DIALECT = 'mysql'
DRIVER = 'mysqlconnector'                          # pip install mysql-connector-python
USER = os.getenv('MYSQL_USER')
PASSWORD = os.getenv('MYSQL_PASSWORD')
HOST = 'localhost'
PORT = '3306'

connection_string = f"{DIALECT}+{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}"
engine = create_engine(connection_string)

# %% [markdown]
# ## 1.2 Create a new database

# %% [markdown]
# - We can use the `execute` method to run arbitrary SQL statements
# - To make sure that the connection to the database is closed after the transaction, we can use the `with` statement.

# %%
with engine.connect() as connection:
    connection.execute(text('CREATE DATABASE IF NOT EXISTS music'))

# %% [markdown]
# - Typically, we would not create a new database in this way, but use a database that already exists.
# - In this case, we would directly specify an engine that points to the existing database.

# %%
connection_string = f"{DIALECT}+{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}/music"
engine = create_engine(connection_string)

# %% [markdown]
# ## 1.3 Write Pandas DataFrame to database

# %% [markdown]
# - We use the `to_sql` method of Pandas DataFrames to write an entire DataFrame to a database table
# - We can specify how to handle the situation that the table already exists: 'fail', 'replace', 'append'
# - Also we need to consider whether the index should be written to the database (default)

# %%
df = pd.read_csv("data/tracks.csv")
df.shape
df.head()
# Out:
#                        id                        name  \
# 0  05Mp2UJulSttxQ4E6hQPH3              Ohne mein Team
# 1  4bHsxqR3GMrXTxEPLuK5ue        Don't Stop Believin'
# 2  3rdAz1fbUfZxYgaCviYhRo                  Todo De Ti
# 3  254bXAqt3zP6P50BdQvEsq  Everywhere - 2017 Remaster
# 4  2PGA1AsJal6cyMNmKyE56q                    200 km/h
#
#                             album_name  \
# 0                   Palmen aus Plastik
# 1                               Escape
# 2                           VICE VERSA
# 3  Tango In the Night (Deluxe Edition)
# 4                               Platte
#
#                                           artist_ids  danceability  energy  \
# 0  1aS5tqEs9ci5P9KD9tZWa6,0Dvx6p8JDyzeOPGmaCIH1L,...         0.766   0.800
# 1                             0rvjqX7ttXeg3mTy8Xscbt         0.500   0.748
# 2                             1mcTU81TzQhprhouKaTkpq         0.780   0.719
# 3                             08GQAI4eElDnROBrJRGE0X         0.730   0.487
# 4                             1qQLhymHXFPtP5U8KNKsm6         0.899   0.670
#
#    speechiness  acousticness  valence    tempo  duration_ms
# 0       0.0938         0.160    0.635  129.999       188504
# 1       0.0363         0.127    0.514  118.852       250987
# 2       0.0506         0.302    0.336  127.962       199604
# 3       0.0303         0.258    0.731  114.965       226653
# 4       0.1630         0.269    0.413  148.065       163147

# %%
df.to_sql(name='tracks', con=engine, if_exists='replace', index=False)
# Out:
# 792

# %% [markdown]
# ## 1.4 Read from database into Pandas DataFrame

# %% [markdown]
# - We can read entire database tables

# %%
tracks = pd.read_sql('tracks', con=engine)
tracks.head()
# Out:
#                        id                        name  \
# 0  05Mp2UJulSttxQ4E6hQPH3              Ohne mein Team
# 1  4bHsxqR3GMrXTxEPLuK5ue        Don't Stop Believin'
# 2  3rdAz1fbUfZxYgaCviYhRo                  Todo De Ti
# 3  254bXAqt3zP6P50BdQvEsq  Everywhere - 2017 Remaster
# 4  2PGA1AsJal6cyMNmKyE56q                    200 km/h
#
#                             album_name  \
# 0                   Palmen aus Plastik
# 1                               Escape
# 2                           VICE VERSA
# 3  Tango In the Night (Deluxe Edition)
# 4                               Platte
#
#                                           artist_ids  danceability  energy  \
# 0  1aS5tqEs9ci5P9KD9tZWa6,0Dvx6p8JDyzeOPGmaCIH1L,...         0.766   0.800
# 1                             0rvjqX7ttXeg3mTy8Xscbt         0.500   0.748
# 2                             1mcTU81TzQhprhouKaTkpq         0.780   0.719
# 3                             08GQAI4eElDnROBrJRGE0X         0.730   0.487
# 4                             1qQLhymHXFPtP5U8KNKsm6         0.899   0.670
#
#    speechiness  acousticness  valence    tempo  duration_ms
# 0       0.0938         0.160    0.635  129.999       188504
# 1       0.0363         0.127    0.514  118.852       250987
# 2       0.0506         0.302    0.336  127.962       199604
# 3       0.0303         0.258    0.731  114.965       226653
# 4       0.1630         0.269    0.413  148.065       163147

# %% [markdown]
# - ... and send arbitrary SQL queries to read data into a Pandas DataFrame

# %%
pd.read_sql('select name, album_name, danceability from tracks order by danceability desc limit 5', con=engine)
# Out:
#            name          album_name  danceability
# 0  Pure Cocaine       Street Gossip         0.964
# 1    Yes Indeed    Harder Than Ever         0.963
# 2      Low Down    My Turn (Deluxe)         0.962
# 3         CAIRO  MAÑANA SERÁ BONITO         0.957
# 4       Players             Players         0.954

# %%
pd.read_sql('select * from tracks where danceability > 0.8', con=engine)
# Out:
#                          id                        name       album_name  \
# 0    2PGA1AsJal6cyMNmKyE56q                    200 km/h           Platte
# 1    6GomT970rCOkKAyyrwJeZi              Move Your Body   Move Your Body
# 2    6hw1Sy9wZ8UCxYGdpKrU6M                      Roller           Platte
# 3    1F205Nl2feOSYSztLNOJAL                        3 Am       Sauce Boyz
# 4    5ddFjrPG8NgQQ6xlOQIVd2     Tú Me Dejaste De Querer     El Madrileño
# ..                      ...                         ...              ...
# 180  24vDSi6wZW34oY8sTrgQf7          BRÛLURES INDIENNES  DIAMANT DU BLED
# 181  7jbu9k6w67hWlhSinmGT3c  COEUR DE ICE (feat. Damso)  DIAMANT DU BLED
# 182  4bGWT7GWjqaO1Sj9ZbUtEG                    FROSTIES  DIAMANT DU BLED
# 183  5R9ZGpFYnzW3WmVGk2uh4J                   L'ARMOIRE  DIAMANT DU BLED
# 184  60vv2FTa31yyaYlJuDC7rI                      Omerta           OMERTA
#
#                                             artist_ids  danceability  energy  \
# 0                               1qQLhymHXFPtP5U8KNKsm6         0.899   0.670
# 1        37czgDRfGMvgRiUKHvnnhj,0aOIluXr131XqrXFwFCFGT         0.848   0.821
# 2                               1qQLhymHXFPtP5U8KNKsm6         0.941   0.758
# 3        5XJDexmWFLWOkjOEjOVX3e,00XhexlJEXQstHimpZN910         0.852   0.613
# 4    5TYxZTjIPqKM8K8NuP9woO,5IbUz6BcOu6IVY512oxavP,...         0.823   0.723
# ..                                                 ...           ...     ...
# 180                             54kCbQZaZWHnwwj9VP2hn4         0.848   0.404
# 181      54kCbQZaZWHnwwj9VP2hn4,2UwqpfQtNuhBwviIC0f2ie         0.851   0.567
# 182                             54kCbQZaZWHnwwj9VP2hn4         0.883   0.785
# 183                             54kCbQZaZWHnwwj9VP2hn4         0.878   0.576
# 184                             6L34dW6SKMSDaGIfYDU19j         0.805     NaN
#
#      speechiness  acousticness  valence    tempo  duration_ms
# 0         0.1630        0.2690    0.413  148.065       163147
# 1         0.0527        0.0169    0.249  125.051       157445
# 2         0.1700        0.0256    0.683  128.017       157093
# 3         0.1080        0.4130    0.576   89.951       208237
# 4         0.2290        0.3110    0.505   83.970       198493
# ..           ...           ...      ...      ...          ...
# 180       0.2430        0.5600    0.416  103.950       177973
# 181       0.2310        0.2150    0.446  119.969       192213
# 182       0.2590        0.2770    0.294  104.029       110267
# 183       0.2080        0.5930    0.243  111.067       165573
# 184       0.1330        0.2740    0.686   95.024        92000
#
# [185 rows x 11 columns]

# %%
pd.read_sql('select count(*), avg(danceability) from tracks', con=engine)
# Out:
#    count(*)  avg(danceability)
# 0       792           0.695527

# %%
tracks = pd.read_sql('tracks', con=engine)
print(tracks.shape[0])
print(tracks.danceability.mean())
# Out:
# 792
# 0.6955265151515151

# %% [markdown]
# ## 1.5 Delete database and clean up

# %% [markdown]
# - Now we want to undo the previous steps, and clean up
# - Caution: this is irreversible!
# - First, we drop the newly created table "tracks" within our "music" database

# %%
# If you want to delete the table and database, then remove the quotes from this code cell
"""
with engine.connect() as connection:
    connection.execute(text("Drop table if exists tracks"))
    connection.execute(text("Drop database if exists music"))
"""

# %% [markdown]
# - To make sure that all open connections to the database are closed, we should explicitly close them at the end of the script

# %%
# If you want to close all open connections, then uncomment the next line

# engine.dispose()

# %% [markdown]
# # Write all music related tables to database

# %%
charts = pd.read_csv('data/charts.csv')
artists = pd.read_csv('data/artists.csv')
tracks = pd.read_csv('data/tracks.csv')
lyrics = pd.read_csv('data/lyrics.csv')

# %%
charts.to_sql(name='charts', con=engine, if_exists='replace', index=False)
artists.to_sql(name='artists', con=engine, if_exists='replace', index=False)
tracks.to_sql(name='tracks', con=engine, if_exists='replace', index=False)
lyrics.to_sql(name='lyrics', con=engine, if_exists='replace', index=False)
# Out:
# 598

# %% [markdown]
# Send a complex SQL statement that joins tables, etc. and only reads in the result of that operation into a Pandas DataFrame

# %%
query = """select * from charts c left join tracks t on c.track_id = t.id order by t.danceability desc limit 10"""
pd.read_sql(query, con=engine)
# Out:
#   country        date  position                track_id  streams  \
# 0      us  2023-03-28       109  577YBGuskWkVDCxZrLRB4v   371849
# 1      us  2023-03-28       130  6vN77lE9LK6HP2DewaN6HZ   348685
# 2      us  2023-03-28        48  5m0yZ33oOy0yYBtdTXuxQe   536204
# 3      es  2023-03-28        33  16dUQ4quIHDe4ZZ0wF1EMN   210791
# 4      de  2023-03-28        56  6UN73IYd0hZxLi8wFPMQij   110455
# 5      gb  2023-03-28        68  531KGXtBroSrOX9LVmiIgc    89990
# 6      us  2023-03-28        33  6UN73IYd0hZxLi8wFPMQij   599242
# 7      gb  2023-03-28        13  6UN73IYd0hZxLi8wFPMQij   174014
# 8      gb  2023-03-28        86  3yfqSUWxFvZELEM4PmlwIR    79954
# 9      de  2023-03-28        64  28yd3NLXZkDi5p9segSvcf   103839
#
#                        id                 name               album_name  \
# 0  577YBGuskWkVDCxZrLRB4v         Pure Cocaine            Street Gossip
# 1  6vN77lE9LK6HP2DewaN6HZ           Yes Indeed         Harder Than Ever
# 2  5m0yZ33oOy0yYBtdTXuxQe             Low Down         My Turn (Deluxe)
# 3  16dUQ4quIHDe4ZZ0wF1EMN                CAIRO       MAÑANA SERÁ BONITO
# 4  6UN73IYd0hZxLi8wFPMQij              Players                  Players
# 5  531KGXtBroSrOX9LVmiIgc            Starlight                Starlight
# 6  6UN73IYd0hZxLi8wFPMQij              Players                  Players
# 7  6UN73IYd0hZxLi8wFPMQij              Players                  Players
# 8  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady  The Marshall Mathers LP
# 9  28yd3NLXZkDi5p9segSvcf        Vergessen wie            Vergessen wie
#
#                                       artist_ids  danceability  energy  \
# 0                         5f7VJjfbwm532GiveGC0ZK         0.964   0.487
# 1  5f7VJjfbwm532GiveGC0ZK,3TVXtAsR1Inumwj472S9r4         0.963   0.346
# 2                         5f7VJjfbwm532GiveGC0ZK         0.962   0.619
# 3  790FomKkXshlbRYZFtlgla,3m5qlPf2OkihLz3dRYnkPA         0.957   0.677
# 4                         6AMd49uBDJfhf30Ak2QR5s         0.954   0.516
# 5                         6Ip8FS7vWT1uKkJSweANQK         0.954   0.367
# 6                         6AMd49uBDJfhf30Ak2QR5s         0.954   0.516
# 7                         6AMd49uBDJfhf30Ak2QR5s         0.954   0.516
# 8                         7dGJo4pcD2V6oG8kP0tJRR         0.949   0.661
# 9                         6rqlONGmPuP2wJVSfliLBI         0.949   0.679
#
#    speechiness  acousticness  valence    tempo  duration_ms
# 0       0.4210       0.00127    0.107  127.050       154024
# 1       0.5300       0.03550    0.562  119.957       142273
# 2       0.4050       0.03540    0.154  127.958       144652
# 3       0.2920       0.48300    0.469  115.000       198667
# 4       0.1600       0.03000    0.624  105.001       139560
# 5       0.2880       0.34100    0.372  124.026       211935
# 6       0.1600       0.03000    0.624  105.001       139560
# 7       0.1600       0.03000    0.624  105.001       139560
# 8       0.0572       0.03020    0.760  104.504       284200
# 9       0.0682       0.04670    0.126  121.025       224445
